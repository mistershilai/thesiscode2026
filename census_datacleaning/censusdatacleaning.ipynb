# %%
import os
import certifi
os.environ['SSL_CERT_FILE'] = certifi.where()
os.environ['REQUESTS_CA_BUNDLE'] = certifi.where()

from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
geolocator = Nominatim(user_agent="botswana_census_geocoder_quick_test")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
try:
    loc = geocode("Gaborone, Botswana", timeout=10)
    print('OK', loc.latitude, loc.longitude) if loc else print('NO_RESULT')
except Exception as e:
    print('ERROR', type(e).__name__, e)
# Out:
# OK -24.6581357 25.9088474

# %%
import os
import pandas as pd

src_candidates = ['census_datacleaning/census_population_2022.csv', 'census_population_2022.csv']
src = next((p for p in src_candidates if os.path.exists(p)), None)
if src is None:
    raise FileNotFoundError('Source census CSV not found; expected one of: ' + ', '.join(src_candidates))

out_paths = ['census_population_2022_deduped.csv', 'census_datacleaning/census_population_2022_deduped.csv']
if any(os.path.exists(p) for p in out_paths):
    existing = [p for p in out_paths if os.path.exists(p)][0]
    print('Deduped census CSV already exists at:', existing)
else:
    print('Reading source:', src)
    df = pd.read_csv(src)

    col_map = {c.lower(): c for c in df.columns}

    def find_col(key_parts):
        for orig_lower, orig in col_map.items():
            if all(k in orig_lower for k in key_parts):
                return orig
        return None

    district_col = find_col(['census', 'district']) or find_col(['district'])
    town_col = find_col(['city', 'town']) or find_col(['village']) or find_col(['citytownvillage'.lower()])

    if district_col is None or town_col is None:
        for cand in ['Census District', 'census_district', 'District']:
            if cand in df.columns:
                district_col = cand
                break
        for cand in ['City/Town/Village', 'city/town/village', 'city_town_village', 'City/Town']:
            if cand in df.columns:
                town_col = cand
                break

    if district_col is None or town_col is None:
        print('Warning: could not confidently detect district/town columns. Using first two columns as keys.')
        district_col, town_col = df.columns[0], df.columns[1]

    print('Using key columns:', district_col, 'and', town_col)
    df[district_col] = df[district_col].astype(str).str.strip()
    df[town_col] = df[town_col].astype(str).str.strip()

    df_dedup = df.drop_duplicates(subset=[district_col, town_col], keep='first').copy()
    print('Rows before:', len(df), 'after dedup:', len(df_dedup))

    for p in out_paths:
        try:
            df_dedup.to_csv(p, index=False)
            print('Wrote deduped census file to', p)
        except Exception as e:
            print('Failed to write', p, e)
# Out:
# Deduped census CSV already exists at: census_population_2022_deduped.csv

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
from tqdm import tqdm

census = pd.read_csv("census_population_2022_deduped.csv")

census.columns = census.columns.str.strip().str.lower().str.replace(" ", "_")

towns = census[["census_district", "city/town/village"]].drop_duplicates().copy()

towns["query"] = towns["city/town/village"] + ", " + towns["census_district"] + ", Botswana"

# %%
import pandas as pd
import pandas.core.common as pcc
import tqdm

def _is_builtin_func(obj):
    import types as _types
    return isinstance(obj, (_types.BuiltinFunctionType, _types.BuiltinMethodType))

try:
    pcc.is_builtin_func = _is_builtin_func
    print('Patched pandas.core.common.is_builtin_func')
except Exception as e:
    print('Failed to patch pandas.core.common.is_builtin_func:', e)

try:
    pd.Series._is_builtin_func = staticmethod(_is_builtin_func)
    print('Patched pd.Series._is_builtin_func')
except Exception as e:
    print('Failed to set pd.Series._is_builtin_func:', e)

try:
    tqdm.pandas = lambda *a, **k: None
    print('Set tqdm.pandas to no-op')
except Exception as e:
    print('Failed to set tqdm.pandas no-op:', e)
# Out:
# Patched pandas.core.common.is_builtin_func
# Patched pd.Series._is_builtin_func
# Set tqdm.pandas to no-op

# %%
geolocator = Nominatim(user_agent="botswana_census_geocoder")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

from tqdm import tqdm
locations = []
for q in tqdm(towns['query'], desc='geocoding', unit='loc'):
    try:
        locations.append(geocode(q, timeout=10))
    except Exception as e:
        print('ERROR for query', q, type(e).__name__, e)
        locations.append(None)

towns['location'] = locations
towns['latitude'] = towns['location'].apply(lambda loc: loc.latitude if loc else None)
towns['longitude'] = towns['location'].apply(lambda loc: loc.longitude if loc else None)
# Out:
# geocoding: 100%|██████████| 8263/8263 [2:23:52<00:00,  1.04s/loc]

# %%
towns.to_csv("census_villages_geocoded.csv", index=False)

# %%
geo = pd.read_csv("../botswana_geocode/census_population_2022_geocoded_google_strict.csv")
import os
pop_path = os.path.join('census_datacleaning','census_population_2022.csv') if os.path.exists(os.path.join('census_datacleaning','census_population_2022.csv')) else 'census_population_2022.csv'
try:
    pop = pd.read_csv(pop_path)
    print('Loaded census_population_2022.csv as CSV:', pop.shape)
except Exception as e:
    try:
        import pyreadstat
        pop, meta = pyreadstat.read_sav(pop_path)
        print('Loaded census_population_2022.csv as SPSS sav (file_format=', getattr(meta, 'file_format', None), ') with shape', pop.shape)
    except Exception as e2:
        raise

if 'DistrictName' not in pop.columns:
    if 'Census District' in pop.columns:
        pop['DistrictName'] = pop['Census District']
    else:
        if 'District' in pop.columns:
            try:
                pop['DistrictName'] = pop['District'].astype(int).map(district_map)
            except Exception:
                pop['DistrictName'] = pop['District'].astype(str)
        else:
            pop['DistrictName'] = ''

geo["merge_key"] = geo["City/Town/Village"].str.strip().str.lower()
pop["merge_key"] = pop["City/Town/Village"].str.strip().str.lower()

merged = pop.merge(geo[["merge_key", "latitude", "longitude"]],
                   on="merge_key",
                   how="left")

merged = merged.drop(columns=["merge_key"])

merged.to_csv("census_population_with_coords.csv", index=False)
print(f"Merged {len(merged)} rows with coordinates")
print(f"Rows with coordinates: {merged['latitude'].notna().sum()}")
# Out:
# Loaded census_population_2022.csv as CSV: (8523, 4)
# Merged 10456 rows with coordinates
# Rows with coordinates: 10427

# %%
import pandas as pd
import pyreadstat

df_raw, meta = pyreadstat.read_sav("botswanacensusmicrodata.sav")
df_raw.shape
# Out:
# (2359609, 131)

# %%
df_raw["NEW_AGE"].describe()
(df_raw["NEW_AGE"] == 999).sum()
# Out:
# np.int64(2695)

# %%
df = df_raw.copy()
df.shape

before = df.shape[0]
df = df[df["NEW_AGE"] != 999]
after = df.shape[0]

before, after, before - after
# Out:
# (2359609, 2356914, 2695)

# %%
df["DistrictCode"] = df["District"].astype(int)
sorted(df["DistrictCode"].unique())
# Out:
# [np.int64(1),
#  np.int64(2),
#  np.int64(3),
#  np.int64(4),
#  np.int64(5),
#  np.int64(6),
#  np.int64(7),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(20),
#  np.int64(21),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(40),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53),
#  np.int64(54),
#  np.int64(55),
#  np.int64(56),
#  np.int64(60),
#  np.int64(70),
#  np.int64(71),
#  np.int64(72),
#  np.int64(73),
#  np.int64(74),
#  np.int64(80),
#  np.int64(81),
#  np.int64(82),
#  np.int64(90),
#  np.int64(91)]

# %%
district_map = {
    1: "Gaborone",
    2: "Francistown",
    3: "Lobatse",
    4: "Selebi-Phikwe",
    5: "Orapa",
    6: "Jwaneng",
    7: "Sowa Town",
    10: "Ngamiland East",
    11: "Barolong",
    12: "Ngwaketse West",
    13: "Ngwaketse Central",
    20: "South East",
    21: "Ngamiland West",
    30: "Kweneng East",
    31: "Kweneng West",
    32: "Kweneng Central",
    40: "Kgatleng",
    50: "Central Serowe-Palapye",
    51: "Central Mahalapye",
    52: "Central Bobonong",
    53: "Central Boteti",
    54: "Central Tutume",
    55: "Central Molalatau",
    56: "Central Madinare",
    60: "North East",
    70: "Kgalagadi South",
    71: "Kgalagadi North",
    72: "Ghanzi",
    73: "CKGR",
    74: "Ghanzi Farms",
    80: "Chobe",
    81: "Kasane",
    82: "Pandamatenga",
    90: "Kgalagadi Rural",
    91: "Tsabong"
}

df["DistrictName"] = df["DistrictCode"].map(district_map)

# %%
df["DistrictName"].isna().sum()
# Out:
# np.int64(0)

# %%
sorted(df["DistrictName"].unique())
# Out:
# ['Barolong',
#  'CKGR',
#  'Central Bobonong',
#  'Central Boteti',
#  'Central Madinare',
#  'Central Mahalapye',
#  'Central Molalatau',
#  'Central Serowe-Palapye',
#  'Central Tutume',
#  'Chobe',
#  'Francistown',
#  'Gaborone',
#  'Ghanzi',
#  'Ghanzi Farms',
#  'Jwaneng',
#  'Kasane',
#  'Kgalagadi North',
#  'Kgalagadi Rural',
#  'Kgalagadi South',
#  'Kgatleng',
#  'Kweneng Central',
#  'Kweneng East',
#  'Kweneng West',
#  'Lobatse',
#  'Ngamiland East',
#  'Ngamiland West',
#  'Ngwaketse Central',
#  'Ngwaketse West',
#  'North East',
#  'Orapa',
#  'Pandamatenga',
#  'Selebi-Phikwe',
#  'South East',
#  'Sowa Town',
#  'Tsabong']

# %%
bins = [-1, 1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 200]

labels = [
    "<1", "1–5", "6–10", "11–15", "16–20",
    "21–25", "26–30", "31–35", "36–40",
    "41–45", "46–50", "51–55", "56–60",
    "61–65", "66+"
]

df["AgeGroup"] = pd.cut(df["NEW_AGE"], bins=bins, labels=labels, right=False)
df["AgeGroup"].isna().sum()
sorted(df["AgeGroup"].unique())
# Out:
# ['11–15',
#  '16–20',
#  '1–5',
#  '21–25',
#  '26–30',
#  '31–35',
#  '36–40',
#  '41–45',
#  '46–50',
#  '51–55',
#  '56–60',
#  '61–65',
#  '66+',
#  '6–10',
#  '<1']

# %%
df["DistrictCode"] = df["District"].astype(int)
df["DistrictName"] = df["DistrictCode"].map(district_map)

pop = (
    df.groupby(["DistrictCode","DistrictName","AgeGroup"])
      .size()
      .reset_index(name="Population")
)

pop = pop.sort_values(["DistrictCode","AgeGroup"])

# %%
district_totals = pop.groupby("DistrictName")["Population"].sum().reset_index()

district_totals[district_totals["Population"] == 0]
pop.groupby("DistrictName")["Population"].sum().sort_values()
# Out:
# DistrictName
# Kasane                       486
# CKGR                         949
# Ghanzi Farms                1919
# Sowa Town                   3264
# Orapa                       8639
# Pandamatenga               17506
# Jwaneng                    18790
# Tsabong                    23482
# Ghanzi                     28707
# Lobatse                    29778
# Ngwaketse West             31967
# Kgalagadi Rural            35322
# Chobe                      38488
# Selebi-Phikwe              42326
# Kweneng West               52287
# Ngwaketse Central          52311
# South East                 55093
# Ngamiland West             57113
# Barolong                   59077
# North East                 69299
# Kgalagadi North            74830
# Central Bobonong           77524
# Central Boteti             78377
# Ngamiland East             78627
# Central Molalatau          80268
# Central Tutume             85789
# Central Serowe-Palapye     94252
# Central Madinare          102882
# Francistown               103285
# Kgalagadi South           120486
# Kgatleng                  121817
# Central Mahalapye         131877
# Kweneng East              138378
# Kweneng Central           196413
# Gaborone                  245306
# Name: Population, dtype: int64

# %%
df["DistrictCode"] = df["District"].astype(int)
df["DistrictName"] = df["DistrictCode"].map(district_map)

pop = (
    df.groupby(["DistrictName","AgeGroup"])
      .size()
      .reset_index(name="Population")
)

pop["DistrictCode"] = pop["DistrictName"].map(
    df[["DistrictName","DistrictCode"]].drop_duplicates().set_index("DistrictName")["DistrictCode"]
)

pop = pop.sort_values(["DistrictName","AgeGroup"]).reset_index(drop=True)

pop.to_csv("botswana_population_age_breakdown.csv", index=False)
